# %%
import pandas as p

# %%
df=p.read_csv('Mini Project (Responses).csv')
df2=p.read_csv('Student.csv')

# %%
df=df.fillna(0)
df=df.astype({"Class Roll of Member 5": int}) 
df.head(2)
# Out:
#             Timestamp   Project domain/Project topic  \
# 0   3-26-2020 1:13:20  ML integrated web application
# 1  3-27-2020 14:52:59      Fitness Management System
#
#                        Describe your project shortly  Class Roll of Member 1  \
# 0  Our web application should take input as a han...                      65
# 1  It will contain 3 module.\n1)Admin 2)Member 3)...                      67
#
#    Class Roll of Member 2  Class Roll of Member 3  Class Roll of Member 4  \
# 0                      80                      83                     110
# 1                      87                      89                      90
#
#    Class Roll of Member 5
# 0                       0
# 1                      91

# %%
df2.head(2)
# Out:
#    Class Roll  STUDENT'S NAME
# 0        63.0  PRAKRITI GHOSH
# 1        64.0    PRALAY GHOSH

# %%
df3=p.DataFrame(columns=['Group No.','Group Name','Roll','Members','Project Name','Project Details'])

# %%
count=0
for i in range(len(df['Timestamp'])):
    df3.at[count,'Group No.']=i+1
    df3.at[count,'Group Name']=df.at[i,'Project domain/Project topic']
    df3.at[count,'Project Name']=df.at[i,'Project domain/Project topic']
    df3.at[count,'Project Details']=df.at[i,'Describe your project shortly']
    for j in range(3,8):
        for k in range(0,68):
            if (df.iat[i,j]==df2.iat[k,0]):
                df3.at[count,'Roll']=int((df2.iat[k,0]))
                df3.at[count,'Members']=df2.iat[k,1]
                count+=1
                break
df3['Roll'].astype(int)
df3.to_csv('output.csv',index=False)
df3
# Out:
#    Group No. Roll                  Members  \
# 0          1   65          PRITIMOY SARKAR
# 1        NaN   80             SANDIPAN SAU
# 2        NaN   83     SASWATA MUKHOPADHYAY
# 3        NaN  110              SUPRIYO DAS
# 4          2   67                 PUJA KAR
# 5        NaN   87              SHIRSHA SEN
# 6        NaN   89            SHOUVIK GHOSH
# 7        NaN   90           SHREETI PANDEY
# 8        NaN   91      SHUBHAM KUMAR NANDI
# 9          3  102             SOUVIK PATRA
# 10       NaN   97       SOUMYA CHAKRABORTY
# 11       NaN  100              SOURAV JANA
# 12       NaN  101            SOUVIK LASKAR
# 13       NaN  122            ARINDAM GHOSH
# 14         4  113  SWARNADIPA  CHAKRABORTY
# 15       NaN  128          SUSANTA DAS (L)
# 16       NaN  129     MAYNAK  KARMAKAR (L)
# 17       NaN  130         NISHA MONDAL (L)
# 18         5  126     SUBHADEEP DEBROY (T)
# 19       NaN  123         ARHIT CHATTERJEE
# 20       NaN   66            PROMISE DUTTA
# 21       NaN  109              SUNIL MAITY
#
#                              Project Name  \
# 0           ML integrated web application
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4               Fitness Management System
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9             Health care web application
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14  Software based project on PHP & MYSQL
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                 Obstacles avoiding car
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
#
#                                       Project Details
# 0   Our web application should take input as a han...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   It will contain 3 module.\n1)Admin 2)Member 3)...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   It simply customer can take any kind of health...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                          Library management system
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  A car remote controlled using smart phone can ...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
